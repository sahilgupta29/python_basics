# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %%
""". This is because Exception is the base class for all built-in exceptions in Python. By inheriting from Exception,
your custom exception will behave similarly to other built-in exceptions, making it easier for users to understand and
handle your custom exception in a consistent manner. Additionally, inheriting from Exception allows your custom exception 
to catch more general exceptions if necessary, providing flexibility in exception handling."""
# Out:
# '. This is because Exception is the base class for all built-in exceptions in Python. By inheriting from Exception,\nyour custom exception will behave similarly to other built-in exceptions, making it easier for users to understand and\nhandle your custom exception in a consistent manner. Additionally, inheriting from Exception allows your custom exception \nto catch more general exceptions if necessary, providing flexibility in exception handling.'

# %% [markdown]
# Q2. Here's a Python program to print the Python Exception Hierarchy:

# %%
import builtins

def print_exception_hierarchy(exception_cls, indent=0):
    print(' ' * indent + exception_cls.__name__)
    for subclass in exception_cls.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(builtins.BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             herror
#             gaierror
#             timeout
#             SSLError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
"""The ArithmeticError class in Python defines errors that occur during arithmetic operations. Two examples of errors defined in this class are 
ZeroDivisionError and OverflowError.

ZeroDivisionError: This error occurs when you try to divide a number by zero.
python"""

try:
    result = 5 / 0
except ZeroDivisionError:
    print("Error: Division by zero!")
# OverflowError: This error occurs when the result of an arithmetic operation exceeds the maximum representable value.

import math
try:
    result = math.exp(1000)
except OverflowError:
    print("Error: Result too large to represent!")
# Out:
# Error: Division by zero!
# Error: Result too large to represent!

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
"""Q4. The LookupError class in Python is used to handle errors related to sequence lookup. Two common subclasses of 
LookupError are KeyError and IndexError."""

# KeyError: This error occurs when a dictionary key is not found.

my_dict = {'a': 1, 'b': 2, 'c': 3}
try:
    value = my_dict['d']
except KeyError:
    print("Error: Key not found in dictionary!")
# IndexError: This error occurs when trying to access an index that is out of range in a sequence like a list or tuple.

my_list = [1, 2, 3]
try:
    value = my_list[3]
except IndexError:
    print("Error: Index out of range!")
# Out:
# Error: Key not found in dictionary!
# Error: Index out of range!

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
"""ImportError in Python is raised when an import statement fails to find the module definition or when a from ... import 
statement fails to find a name that is to be imported.

ModuleNotFoundError is a subclass of ImportError. It is raised when a module could not be found."""


try:
    import non_existent_module
except ImportError:
    print("Error: Module import failed!")

try:
    from non_existent_module import some_function
except ModuleNotFoundError:
    print("Error: Module not found!")
# Out:
# Error: Module import failed!
# Error: Module not found!

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
"""Specificity: Handle exceptions as specifically as possible. This allows you to differentiate between different types 
of errors and handle them appropriately.
Try-Except Blocks: Use try-except blocks to catch and handle exceptions gracefully.
Avoid Bare Excepts: Avoid using bare excepts (except:) as they catch all exceptions, including system-exiting exceptions 
like KeyboardInterrupt.
Cleanup with Finally: Use the finally block to ensure that cleanup code (such as closing files or releasing resources) is
executed regardless of whether an exception occurs.
Logging: Use logging to record details about exceptions. This helps in debugging and monitoring applications.
Raising Exceptions: Raise exceptions when necessary to signal errors or unexpected conditions.
Keep It Simple: Keep exception handling logic simple and easy to understand.
Handle Exceptions Locally: Handle exceptions at an appropriate level of abstraction, usually close to where they occur.
Document Exceptions: Document which exceptions a function may raise to help users understand how to handle them.
By following these best practices, you can write robust and maintainable code with effective exception handling in Python.






"""
# Out:
# 'Specificity: Handle exceptions as specifically as possible. This allows you to differentiate between different types \nof errors and handle them appropriately.\nTry-Except Blocks: Use try-except blocks to catch and handle exceptions gracefully.\nAvoid Bare Excepts: Avoid using bare excepts (except:) as they catch all exceptions, including system-exiting exceptions \nlike KeyboardInterrupt.\nCleanup with Finally: Use the finally block to ensure that cleanup code (such as closing files or releasing resources) is\nexecuted regardless of whether an exception occurs.\nLogging: Use logging to record details about exceptions. This helps in debugging and monitoring applications.\nRaising Exceptions: Raise exceptions when necessary to signal errors or unexpected conditions.\nKeep It Simple: Keep exception handling logic simple and easy to understand.\nHandle Exceptions Locally: Handle exceptions at an appropriate level of abstraction, usually close to where they occur.\nDocument Exceptions: 
# ...
